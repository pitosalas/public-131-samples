# %%
import graphviz

# %%
xxx = graphviz.Digraph('x', comment='x')

# %%
xxx

# %%
print(1)
# Out:
# 1

# %%
print(dot.source)
# Out:
# // The Round Table
# digraph "round-table" {
# }

# %%
dot.render(directory='doctest-output', view=True)  
'doctest-output/round-table.gv.pdf'
# Out:
# 'doctest-output/round-table.gv.pdf'

# %%
s = graphviz.Digraph('memory', filename='memory.gv',
                     node_attr={'shape': 'record'})

s.node('mainmem', r'{ 1 | 2|  <x>3-5| 6 | 7 | 8}')
s.node('p1', r'{  <head> 1 |2}')
s.node('p2', r'{<head>1 |  <y> 2}')
s.edges([('mainmem:x', 'p1:head')],[('mainmem:x', 'p2:head')])


s.view()
# Out:
#   Cell In[48], line 7
#     s.edges([('mainmem:x', 'p1:head')],[('mainmem:x', 'p2:head')]
#            ^
# SyntaxError: '(' was never closed
